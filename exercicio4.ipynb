# %%
# Criar um array com 4 linhas e 5 colunas
array_ex4 = np.arange(20).reshape(4, 5) # Cria um array de 0 a 19 e o remodela para 4x5
print("Array:\n", array_ex4)

# Imprimir os elementos da terceira linha (índice 2)
print("Elementos da terceira linha:", array_ex4[2, :])
