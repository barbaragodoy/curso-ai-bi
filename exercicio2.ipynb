# %%
# Criar um array com 3 linhas e 2 colunas
array_ex2 = np.array([[1, 2], [3, 4], [5, 6]])
print("Array:\n", array_ex2)

# Imprimir o shape do array
print("Shape do array:", array_ex2.shape)

# Imprimir a 2ª linha (índice 1)
print("2ª linha do array:", array_ex2[1, :])
