# %%
# Criar um array com 3 linhas e 2 colunas (reutilizando o do Exercício 2 para consistência)
array_ex3 = np.array([[10, 20], [30, 40], [50, 60]])
print("Array:\n", array_ex3)

# Imprimir a 2ª coluna (índice 1)
print("2ª coluna do array:", array_ex3[:, 1])
