# %%
# Criar um array com 4 linhas e 5 colunas (reutilizando o do Exercício 4 para consistência)
array_ex5 = np.arange(20).reshape(4, 5)
print("Array original:\n", array_ex5)

# Imprimir elementos da primeira e segunda linhas (índices 0 e 1)
# e da segunda a terceira colunas (índices 1 e 2)
# Fatiamento para linhas: 0:2 (exclui o índice 2, então inclui 0 e 1)
# Fatiamento para colunas: 1:3 (exclui o índice 3, então inclui 1 e 2)
subset_array_ex5 = array_ex5[0:2, 1:3]
print("Elementos selecionados:\n", subset_array_ex5)
