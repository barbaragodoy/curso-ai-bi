# %%
import numpy as np

# Exercício 1: criar array de 10 elementos
arr = np.arange(10)

# alterar valores de índices 5 a 8 para 0
arr[5:9] = 0  # inclui índice 8

arr
# Out:
# array([0, 1, 2, 3, 4, 0, 0, 0, 0, 9])
